# %%
import pandas as pd
import numpy as np
import openpyxl
import fastparquet

# %%
sheets = [
    {
        "name": "Table 2",
        "type": "Division",
        "skiprows": 6,
        "cols": ["description", "code"],
        "measure": "Value £ million"
    },
    {
        "name": "Table 3",
        "type": "Industry",
        "skiprows": 6,
        "cols": ["parent_description", "code", "description"],
        "measure": "Value £ million"
    },
    {
        "name": "Table 5",
        "type": "Product",
        "skiprows": 5,
        "cols": ["code", "description", "measure"]
    },
]

dfs = []
for sheet in sheets:
    df = pd.read_excel(
        "prodcom_accessiblepublicationtables2024.xlsx",
        sheet_name=sheet["name"],
        skiprows=sheet["skiprows"],
        dtype=str
    )
    df["type"] = sheet["type"]
    df.columns = sheet["cols"] + list(df.columns[len(sheet["cols"]):])
    if "measure" in sheet:
        df["measure"] = sheet["measure"]
    dfs.append(df)

df = pd.concat(dfs, ignore_index=True)

# Keep the description, code, parent_description and years cols
df = df[["description", "code", "parent_description", "type", "measure"] + [col for col in df.columns if col.startswith("20")]]
# Rename the measure to unit
df = df.rename(columns={"measure": "unit"})

df = df.melt(id_vars=["description", "code", "parent_description", "type", "unit"], var_name="year", value_name="value")

# Extract any [square bracketed text] from the value to get the flags
df['flag'] = df['value'].str.extract(r'\[(.*?)\]')
df.flag.value_counts(dropna=False)


# # Remove the flags and commas from the value and convert to numeric
df['value'] = df['value'].astype(str).str.replace(r'\[.*?\]', '', regex=True)
df['value'] = df['value'].astype(str).str.replace(r',', '', regex=True)
df['value'] = pd.to_numeric(df['value'], errors='coerce')

# A value of zero in the data corresponds to no data collected, add this to the flag
df['flag'] = np.where(df['value']==0,"0",df['flag'])

# To keep flags for missing data, set all nan values to 0 instead of dropping OR keep nan values altogether
df = df.dropna(subset=['value'])
# df['value']=df['value'].fillna(0)

df['flag'] = df['flag'].map({
    "e": "e - low response; high level of estimation",
    "c": "c - data suppressed; data is disclosive",
    "a": "a - data suppressed; data is disclosive and is aggregated within the UK Manufacturer Sales of 'Other' products",
    "x": "x - data not available",
    "0": "No data collected"
})

# Use 'measure' to group by value, volume, or average price
df['measure'] = np.where(df['unit'].str.contains('Value', case=False), 'Value',
                         np.where(df['unit'].str.contains('Volume', case=False), 'Volume',
                                  'Average price/Other'))

df['code'] = df.code.astype(str)

df.to_parquet("prodcom.parquet", index=False)

# %%
df[["description", "code", "type"]].drop_duplicates().to_json("cn8_division_industry_product.json", orient="records", force_ascii=False)

# %%
df.columns
# Out:
# Index(['description', 'code', '2014', '2015', '2016', '2017', '2018', '2019',
#        '2020', '2021', '2022', '2023', '2024', 'type', 'measure',
#        'parent_description', 'notes'],
#       dtype='object')

# %%
df.measure.unique()
# Out:
# array(['Value', 'Volume', 'Average price/Other'], dtype=object)

# %%
df.year.unique()
# Out:
# array(['2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021',
#        '2022', '2023', '2024'], dtype=object)

# %%
df.type.unique()
# Out:
# array(['Division', 'Industry', 'Product'], dtype=object)

# %%
df.query("code == -1")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 df.query("code == -1")
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/frame.py:4828, in DataFrame.query(self, expr, inplace, **kwargs)
#    4826 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4827 kwargs["target"] = None
# -> 4828 res = self.eval(expr, **kwargs)
#    4830 try:
#    4831     result = self.loc[res]
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/frame.py:4954, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4951     kwargs["target"] = self
#    4952 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4954 return _eval(expr, inplace=inplace, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/computation/eval.py:339, in eval(expr, parser, engine, local_dict, global_dict, resolvers, level, target, inplace)
#     330 # get our (possibly passed-in) scope
#     331 env = ensure_scope(
#     332     level + 1,
#     333     global_dict=global_dict,
#    (...)
#     336     target=target,
#     337 )
# --> 339 parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     341 if engine == "numexpr" and (
#     342     (
#     343         is_extension_array_dtype(parsed_expr.terms.return_type)
#    (...)
#     350     )
#     351 ):
#     352     warnings.warn(
#     353         "Engine has switched to 'python' because numexpr does not support "
#     354         "extension array dtypes. Please set your engine to python manually.",
#     355         RuntimeWarning,
#     356         stacklevel=find_stack_level(),
#     357     )
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:809, in Expr.__init__(self, expr, engine, parser, env, level)
#     807 self.parser = parser
#     808 self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 809 self.terms = self.parse()
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:828, in Expr.parse(self)
#     824 def parse(self):
#     825     """
#     826     Parse an expression.
#     827     """
# --> 828     return self._visitor.visit(self.expr)
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:413, in BaseExprVisitor.visit(self, node, **kwargs)
#     411 method = f"visit_{type(node).__name__}"
#     412 visitor = getattr(self, method)
# --> 413 return visitor(node, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:419, in BaseExprVisitor.visit_Module(self, node, **kwargs)
#     417     raise SyntaxError("only a single expression is allowed")
#     418 expr = node.body[0]
# --> 419 return self.visit(expr, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:413, in BaseExprVisitor.visit(self, node, **kwargs)
#     411 method = f"visit_{type(node).__name__}"
#     412 visitor = getattr(self, method)
# --> 413 return visitor(node, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:422, in BaseExprVisitor.visit_Expr(self, node, **kwargs)
#     421 def visit_Expr(self, node, **kwargs):
# --> 422     return self.visit(node.value, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:413, in BaseExprVisitor.visit(self, node, **kwargs)
#     411 method = f"visit_{type(node).__name__}"
#     412 visitor = getattr(self, method)
# --> 413 return visitor(node, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:719, in BaseExprVisitor.visit_Compare(self, node, **kwargs)
#     717     op = self.translate_In(ops[0])
#     718     binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 719     return self.visit(binop)
#     721 # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#     722 left = node.left
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:413, in BaseExprVisitor.visit(self, node, **kwargs)
#     411 method = f"visit_{type(node).__name__}"
#     412 visitor = getattr(self, method)
# --> 413 return visitor(node, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:537, in BaseExprVisitor.visit_BinOp(self, node, **kwargs)
#     535 op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     536 left, right = self._maybe_downcast_constants(left, right)
# --> 537 return self._maybe_evaluate_binop(op, op_class, left, right)
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:531, in BaseExprVisitor._maybe_evaluate_binop(self, op, op_class, lhs, rhs, eval_in_python, maybe_eval_in_python)
#     522 elif self.engine != "pytables":
#     523     if (
#     524         getattr(lhs, "return_type", None) == object
#     525         or is_string_dtype(getattr(lhs, "return_type", None))
#    (...)
#     529         # evaluate "==" and "!=" in python if either of our operands
#     530         # has an object or string return type
# --> 531         return self._maybe_eval(res, eval_in_python + maybe_eval_in_python)
#     532 return res
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/computation/expr.py:489, in BaseExprVisitor._maybe_eval(self, binop, eval_in_python)
#     482 def _maybe_eval(self, binop, eval_in_python):
#     483     # eval `in` and `not in` (for now) in "partial" python space
#     484     # things that can be evaluated in "eval" space will be turned into
#    (...)
#     487     # in that case a + 2 * b will be evaluated using numexpr, and the "in"
#     488     # call will be evaluated using isin (in python space)
# --> 489     return binop.evaluate(
#     490         self.env, self.engine, self.parser, self.term_type, eval_in_python
#     491     )
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/computation/ops.py:417, in BinOp.evaluate(self, env, engine, parser, term_type, eval_in_python)
#     406 else:
#     407     # recurse over the left/right nodes
#     409     left = self.lhs.evaluate(
#     410         env,
#     411         engine=engine,
#    (...)
#     414         eval_in_python=eval_in_python,
#     415     )
# --> 417     right = self.rhs.evaluate(
#     418         env,
#     419         engine=engine,
#     420         parser=parser,
#     421         term_type=term_type,
#     422         eval_in_python=eval_in_python,
#     423     )
#     425     # base cases
#     426     if self.op in eval_in_python:
#
# AttributeError: 'UnaryOp' object has no attribute 'evaluate'

# %%
# What non-numeric codes do we have?
df[df.code.astype(str).str.contains(r'\D')].code.unique()
# Out:
# array(['All Divisions', 'Industry Total', '11 & 12'], dtype=object)

# %%
df.sample(100)
# Out:
#                                               description      code  \
# 23275   10122080  (CN 02071491 + 02072791 + 02074593 +...  10122080
# 68334   Manufacture of electric motors, generators and...     27110
# 28256   22231290  (CN 392290), Plastic bidets; lavator...  22231290
# 56967               Manufacture of electronic components      26110
# 66802   28921100  (CN 842831), Continuous-action eleva...  28921100
# ...                                                   ...       ...
# 98384   26112180  (CN 854130), Semiconductor thyristor...  26112180
# 16978   22299160, Plastic parts and accessories for al...  22299160
# 114335  10311460  (CN 20052020 + 20052080), Potatoes p...  10311460
# 9907    28491150  (CN 846420), Grinding or polishing m...  28491150
# 115860  14133542  (CN 62046231), Women's and girls' tr...  14133542
#
#                                        parent_description      type  \
# 23275                                                 NaN   Product
# 68334                 Manufacture of electrical equipment  Industry
# 28256                                                 NaN   Product
# 56967   Manufacture of computer; electronic and optica...  Industry
# 66802                                                 NaN   Product
# ...                                                   ...       ...
# 98384                                                 NaN   Product
# 16978                                                 NaN   Product
# 114335                                                NaN   Product
# 9907                                                  NaN   Product
# 115860                                                NaN   Product
#
#                          unit  year         value flag              measure
# 23275          £ per Kilogram  2016  8.500000e-01  NaN  Average price/Other
# 68334         Value £ million  2020  1.294000e+03  NaN                Value
# 28256   £ per Number of items  2016  6.470000e+00  NaN  Average price/Other
# 56967         Value £ million  2019  1.111000e+03  NaN                Value
# 66802            Value £000's  2019  5.209400e+04  NaN                Value
# ...                       ...   ...           ...  ...                  ...
# 98384   £ per Number of items  2022  1.059700e+02  NaN  Average price/Other
# 16978            Value £000's  2015  1.225444e+06  NaN                Value
# 114335      Volume (Kilogram)  2024  1.888676e+08  NaN               Volume
# 9907    £ per Number of items  2014  1.377465e+04  NaN  Average price/Other
# 115860  £ per Number of items  2024  4.350000e+00  NaN  Average price/Other
#
# [100 rows x 9 columns]

# %%
pd.DataFrame(df.measure.value_counts(dropna=False)).head(30)
# Out:
#                               count
# measure
# Value £000's                   4051
# Volume (Kilogram)              1587
# £ per Kilogram                 1587
# Volume (Number of items)       1197
# £ per Number of items          1197
# Volume (Tonnes)                 368
# £ per Tonnes                    368
# Value £ million                 258
# £ per Square metre               97
# Volume (Square metre)            97
# £ per Cubic metre                39
# Volume (Cubic metre)             39
# £ per Number of pairs            32
# Volume (Number of pairs)         32
# Volume (Litre)                   31
# £ per Litre                      31
# Volume (Thousand items)          29
# Volume (Kg of active subst.)     29
# £ per Kg of active subst.        29
# £ per Thousand items             29
# £ per Kg N                       21
# Volume (Kg N)                    21
# Volume (CGT)                     18
# £ per CGT                        18
# Volume (Thou cubic metres)        7
# Volume (Hundred items)            7
# £ per Kg P2O5                     7
# Volume (Kg P2O5)                  7
# £ per Thou cubic metres           7
# £ per Hundred items               7

# %%
df.measu

# %%
dfs[2]
# Out:
#        08111133  \
# 0       8111133
# 1       8111133
# 2       8111136
# 3       8111136
# 4       8111136
# ...         ...
# 11093  33205050
# 11094  33205090
# 11095  33206000
# 11096  33207000
# 11097  33208999
#
#       08111133  (CN 251511), Marble and travertine, crude or roughly trimmed  \
# 0      08111133  (CN 251511), Marble and travertine, ...
# 1      08111133  (CN 251511), Marble and travertine, ...
# 2      08111136  (CN 251512), Marble and travertine m...
# 3      08111136  (CN 251512), Marble and travertine m...
# 4      08111136  (CN 251512), Marble and travertine m...
# ...                                                  ...
# 11093  33205050,  Installation of electricity distrib...
# 11094  33205090,  Installation of electrical equipmen...
# 11095  33206000,  Installation of industrial process ...
# 11096  33207000,  Installation of non-domestic time m...
# 11097  33208999,  Installation of military weapons an...
#
#           Value £000's          [a]       0     0.1     0.2     0.3     0.4  \
# 0      Volume (Tonnes)          [c]       0       0       0       0       0
# 1         £ per Tonnes          [c]     [x]     [x]     [x]     [x]     [x]
# 2         Value £000's          [a]       0       0       0       0       0
# 3      Volume (Tonnes)          [c]       0       0       0       0       0
# 4         £ per Tonnes          [c]     [x]     [x]     [x]     [x]     [x]
# ...                ...          ...     ...     ...     ...     ...     ...
# 11093     Value £000's       243789  265229  237617  213739  246739  220894
# 11094     Value £000's        18750   19263   20476   14595   14756   15485
# 11095     Value £000's       934563  849463  750552  655150  438710  456097
# 11096     Value £000's          778     686     588     934    1288    1449
# 11097     Value £000's  404,409 [e]     [a]     [a]     [a]     [a]     [a]
#
#           0.5     0.6     0.7     0.8     0.9 Unnamed: 14     type
# 0           0       0       0       0       0         NaN  Product
# 1         [x]     [x]     [x]     [x]     [x]         NaN  Product
# 2           0       0       0       0       0         NaN  Product
# 3           0       0       0       0       0         NaN  Product
# 4         [x]     [x]     [x]     [x]     [x]         NaN  Product
# ...       ...     ...     ...     ...     ...         ...      ...
# 11093  219153  107084  137971   87059   90775         NaN  Product
# 11094   72776   75425   52829   85306   88289         NaN  Product
# 11095  408604  645473  538092  562079  447829         NaN  Product
# 11096    1639    2354    1439     [a]     [a]         NaN  Product
# 11097     [a]     [a]     [a]     [a]     [a]         NaN  Product
#
# [11098 rows x 16 columns]
